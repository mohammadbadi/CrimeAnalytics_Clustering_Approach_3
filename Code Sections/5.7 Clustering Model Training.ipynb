# %% [markdown]
# <a href="https://colab.research.google.com/github/Maddi007-Py/Maddi007-Py-CrimeAnalytics_Clustering/blob/main/Code%20Sections/5.7%20Clustering%20Model%20Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **5.7 Clustering Model Training**

# %%
import itertools
import numpy as np
import pandas as pd
import time
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.preprocessing import StandardScaler
import warnings
from IPython.display import display, HTML

print("\n\n")
warnings.filterwarnings("ignore")

# Define feature list
features = [
    'OCC_YEAR', 'OCC_DOY', 'OCC_HOUR', 'LONG_WGS84', 'LAT_WGS84',
    'OCC_Month_Encoded', 'OCC_DOW_Encoded', 'Hood_158_Encoded', 'Division_Encoded',
    'Location_Engineered_Other', 'Location_Engineered_Public', 'Location_Engineered_Residential'
]

# Generate feature combinations (sizes 4, 5, 6)
all_combinations = [list(combo) for r in range(4, 7) for combo in itertools.combinations(features, r)]

# Save feature combinations to CSV
pd.DataFrame(all_combinations).to_csv('Feature_Combo_Current.csv', index=False)
display(HTML("<p style='color: green; font-size:16px;'><b> Feature sets saved to 'Feature_Combo_Current.csv'</b></p>"))

# Load data
url = "https://raw.githubusercontent.com/Maddi007-Py/Maddi007-Py-CrimeAnalytics_Clustering/refs/heads/main/Output_CSV/FE_Encoded.csv"
data = pd.read_csv(url)

# Sample 10% of data
sample_data = data.sample(frac=0.1, random_state=42)

# Track results
set_counters = {}
total_models = 0

# HTML Styling
def color_score(value, reverse=False):
    """Color code scores: Green = good, Yellow = medium, Red = poor"""
    if reverse:
        colors = ["#ff6347", "#ffcc00", "#32cd32"]  # Red → Yellow → Green (lower is better)
    else:
        colors = ["#32cd32", "#ffcc00", "#ff6347"]  # Green → Yellow → Red (higher is better)

    if value < 0.3:
        color = colors[0]
    elif value < 0.6:
        color = colors[1]
    else:
        color = colors[2]

    return f"<span style='color: {color}; font-weight: bold;'>{value:.2f}</span>"

# Iterate over feature sets
for i, feature_set in enumerate(all_combinations):
    total_models += 1

    # Select valid features
    valid_features = [f for f in feature_set if f in sample_data.columns]
    data_for_clustering = sample_data[valid_features]

    # Standardization
    numerical_cols = data_for_clustering.select_dtypes(include=['int64', 'float64']).columns.tolist()
    scaler = StandardScaler()
    data_scaled = pd.DataFrame(scaler.fit_transform(data_for_clustering[numerical_cols]), columns=numerical_cols)

    # Handle categorical data
    categorical_cols = [col for col in valid_features if col not in numerical_cols]
    if categorical_cols:
        data_scaled = pd.concat([data_scaled, data_for_clustering[categorical_cols]], axis=1)

    # KMeans Clustering
    kmeans = KMeans(n_clusters=4, random_state=42)
    kmeans_labels = kmeans.fit_predict(data_scaled)

    # DBSCAN Clustering
    dbscan = DBSCAN(eps=0.5, min_samples=5)
    dbscan_labels = dbscan.fit_predict(data_scaled)

    # Calculate metrics
    silhouette_kmeans = silhouette_score(data_scaled, kmeans_labels)
    dbi_kmeans = davies_bouldin_score(data_scaled, kmeans_labels)
    ch_kmeans = calinski_harabasz_score(data_scaled, kmeans_labels)

    silhouette_dbscan = -1 if len(set(dbscan_labels)) <= 1 else silhouette_score(data_scaled, dbscan_labels)
    dbi_dbscan = -1 if len(set(dbscan_labels)) <= 1 else davies_bouldin_score(data_scaled, dbscan_labels)

    # Assign color-coded values
    results_html = f"""
    <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
        <p><b>Feature Set {i+1}:</b> {', '.join(valid_features)}</p>
        <p>KMeans Silhouette Score: {color_score(silhouette_kmeans)}</p>
        <p>KMeans Davies-Bouldin Index: {color_score(dbi_kmeans, reverse=True)}</p>
        <p>KMeans Calinski-Harabasz Score: {color_score(ch_kmeans)}</p>
        <p>DBSCAN Silhouette Score: {color_score(silhouette_dbscan) if silhouette_dbscan != -1 else 'N/A'}</p>
        <p>DBSCAN Davies-Bouldin Index: {color_score(dbi_dbscan, reverse=True) if dbi_dbscan != -1 else 'N/A'}</p>
    </div>
    """
    display(HTML(results_html))
    time.sleep(0.1)  # Small delay for real-time effect

# Display total models trained
display(HTML(f"<h2 style='color: navy; font-size:18px;'><b> Total Models Trained: {total_models}</b></h2>"))

print("\n\n")

display(HTML(f"""
<div style="font-family: Arial, sans-serif; font-size: 18px; padding: 15px; border-radius: 10px;
             background: #282c34; color: #61dafb; text-align: center; width: 60%; margin: 20px auto;
             box-shadow: 2px 2px 10px rgba(0,0,0,0.2);">
    <strong>Total K-Means & DBCSCAN Clustering models trained:</strong> <span style="color: #ffcc00; font-size: 22px;">{total_models}</span>
</div>
"""))
# Out:
# <p style='color: green; font-size:16px;'><b> Feature sets saved to 'Feature_Combo_Current.csv'</b></p>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 1:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, LONG_WGS84</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.20</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.43</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1332.65</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.02</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.80</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, LAT_WGS84</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.38</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1429.87</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.01</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.27</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 3:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, OCC_Month_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.30</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.28</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2552.11</span></p>
#         <p>DBSCAN Silhouette Score: N/A</p>
#         <p>DBSCAN Davies-Bouldin Index: N/A</p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 4:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, OCC_DOW_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.22</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.35</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1443.28</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.26</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.56</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 5:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, Hood_158_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.28</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.18</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2094.65</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.38</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.58</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 6:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.40</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1322.29</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.01</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.13</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 7:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.33</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.05</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2527.85</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.45</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.07</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 8:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.49</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1520.10</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.17</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.36</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 9:</b> OCC_YEAR, OCC_DOY, OCC_HOUR, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.31</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.29</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1787.87</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.17</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.49</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 10:</b> OCC_YEAR, OCC_DOY, LONG_WGS84, LAT_WGS84</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.24</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.28</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1763.22</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.02</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.38</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 11:</b> OCC_YEAR, OCC_DOY, LONG_WGS84, OCC_Month_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.29</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.26</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2536.94</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.20</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.07</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 12:</b> OCC_YEAR, OCC_DOY, LONG_WGS84, OCC_DOW_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.20</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.39</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1348.53</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.18</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.77</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 13:</b> OCC_YEAR, OCC_DOY, LONG_WGS84, Hood_158_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.27</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.20</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2271.57</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.29</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.81</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 14:</b> OCC_YEAR, OCC_DOY, LONG_WGS84, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.25</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.50</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1903.12</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.05</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.31</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 15:</b> OCC_YEAR, OCC_DOY, LONG_WGS84, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.30</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.10</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2328.16</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.48</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.46</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 16:</b> OCC_YEAR, OCC_DOY, LONG_WGS84, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.43</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1522.33</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.23</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.46</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 17:</b> OCC_YEAR, OCC_DOY, LONG_WGS84, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.24</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.34</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1519.47</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.24</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.55</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 18:</b> OCC_YEAR, OCC_DOY, LAT_WGS84, OCC_Month_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.28</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.30</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2462.36</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.23</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.37</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 19:</b> OCC_YEAR, OCC_DOY, LAT_WGS84, OCC_DOW_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.20</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.43</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1314.89</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.10</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.84</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 20:</b> OCC_YEAR, OCC_DOY, LAT_WGS84, Hood_158_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.18</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1981.11</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.07</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.60</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 21:</b> OCC_YEAR, OCC_DOY, LAT_WGS84, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.23</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.41</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1493.43</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.07</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.91</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 22:</b> OCC_YEAR, OCC_DOY, LAT_WGS84, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.29</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.10</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2321.76</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.45</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.41</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 23:</b> OCC_YEAR, OCC_DOY, LAT_WGS84, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.42</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1557.20</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.79</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 24:</b> OCC_YEAR, OCC_DOY, LAT_WGS84, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.46</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1552.00</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.20</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.35</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 25:</b> OCC_YEAR, OCC_DOY, OCC_Month_Encoded, OCC_DOW_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.29</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.09</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2411.92</span></p>
#         <p>DBSCAN Silhouette Score: N/A</p>
#         <p>DBSCAN Davies-Bouldin Index: N/A</p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 26:</b> OCC_YEAR, OCC_DOY, OCC_Month_Encoded, Hood_158_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.41</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>0.84</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>3941.26</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.50</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>0.86</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 27:</b> OCC_YEAR, OCC_DOY, OCC_Month_Encoded, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.30</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.25</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2638.98</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.07</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.60</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 28:</b> OCC_YEAR, OCC_DOY, OCC_Month_Encoded, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.44</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>0.78</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>4473.69</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.56</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>0.76</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 29:</b> OCC_YEAR, OCC_DOY, OCC_Month_Encoded, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.34</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.19</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2760.35</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.29</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.60</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 30:</b> OCC_YEAR, OCC_DOY, OCC_Month_Encoded, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.35</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.14</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2903.46</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.30</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.58</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 31:</b> OCC_YEAR, OCC_DOY, OCC_DOW_Encoded, Hood_158_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.18</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1957.31</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.37</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.70</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 32:</b> OCC_YEAR, OCC_DOY, OCC_DOW_Encoded, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.41</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1338.70</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.03</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.34</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 33:</b> OCC_YEAR, OCC_DOY, OCC_DOW_Encoded, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.30</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.11</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2298.05</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.47</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.25</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 34:</b> OCC_YEAR, OCC_DOY, OCC_DOW_Encoded, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.47</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1519.50</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.27</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.65</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 35:</b> OCC_YEAR, OCC_DOY, OCC_DOW_Encoded, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.24</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.29</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1558.27</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.22</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.50</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 36:</b> OCC_YEAR, OCC_DOY, Hood_158_Encoded, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.29</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.14</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2364.84</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.18</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.61</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 37:</b> OCC_YEAR, OCC_DOY, Hood_158_Encoded, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.35</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>0.99</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2351.35</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.54</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.09</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 38:</b> OCC_YEAR, OCC_DOY, Hood_158_Encoded, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.35</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.05</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2453.79</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.34</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.28</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 39:</b> OCC_YEAR, OCC_DOY, Hood_158_Encoded, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.36</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.04</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2521.49</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.34</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.35</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 40:</b> OCC_YEAR, OCC_DOY, Division_Encoded, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.30</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.11</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2322.80</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.15</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.90</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 41:</b> OCC_YEAR, OCC_DOY, Division_Encoded, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.33</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1544.56</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.12</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.16</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 42:</b> OCC_YEAR, OCC_DOY, Division_Encoded, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.27</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.51</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1567.69</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.12</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.19</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 43:</b> OCC_YEAR, OCC_DOY, Location_Engineered_Other, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.38</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>0.96</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2945.02</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.37</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.07</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 44:</b> OCC_YEAR, OCC_DOY, Location_Engineered_Other, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.38</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>0.96</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2928.79</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.38</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.07</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 45:</b> OCC_YEAR, OCC_DOY, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.37</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.14</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>3489.81</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.36</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.32</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 46:</b> OCC_YEAR, OCC_HOUR, LONG_WGS84, LAT_WGS84</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.53</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1474.40</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.02</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.38</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 47:</b> OCC_YEAR, OCC_HOUR, LONG_WGS84, OCC_Month_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.22</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.47</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1313.53</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.20</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.71</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 48:</b> OCC_YEAR, OCC_HOUR, LONG_WGS84, OCC_DOW_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.37</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1433.55</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.14</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.39</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 49:</b> OCC_YEAR, OCC_HOUR, LONG_WGS84, Hood_158_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.33</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.05</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2669.19</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.16</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 50:</b> OCC_YEAR, OCC_HOUR, LONG_WGS84, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.27</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.44</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1924.05</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.08</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.61</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 51:</b> OCC_YEAR, OCC_HOUR, LONG_WGS84, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.33</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.04</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2538.37</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.46</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.05</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 52:</b> OCC_YEAR, OCC_HOUR, LONG_WGS84, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.23</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.36</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1409.48</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.24</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.58</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 53:</b> OCC_YEAR, OCC_HOUR, LONG_WGS84, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.31</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.27</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1791.16</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.20</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.85</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 54:</b> OCC_YEAR, OCC_HOUR, LAT_WGS84, OCC_Month_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.38</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1431.30</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.01</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.40</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 55:</b> OCC_YEAR, OCC_HOUR, LAT_WGS84, OCC_DOW_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.22</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.33</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1444.38</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.26</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.94</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 56:</b> OCC_YEAR, OCC_HOUR, LAT_WGS84, Hood_158_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.25</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.25</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1480.76</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.02</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.24</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 57:</b> OCC_YEAR, OCC_HOUR, LAT_WGS84, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.25</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.26</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1689.14</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.09</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.86</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 58:</b> OCC_YEAR, OCC_HOUR, LAT_WGS84, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.28</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.15</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2229.99</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.47</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.23</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 59:</b> OCC_YEAR, OCC_HOUR, LAT_WGS84, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.31</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.27</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1800.87</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.42</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 60:</b> OCC_YEAR, OCC_HOUR, LAT_WGS84, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.24</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.26</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1567.87</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.21</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 61:</b> OCC_YEAR, OCC_HOUR, OCC_Month_Encoded, OCC_DOW_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.37</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1440.09</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.08</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.41</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 62:</b> OCC_YEAR, OCC_HOUR, OCC_Month_Encoded, Hood_158_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.23</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1456.30</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.49</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 63:</b> OCC_YEAR, OCC_HOUR, OCC_Month_Encoded, Division_Encoded</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.41</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1336.30</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.01</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.30</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 64:</b> OCC_YEAR, OCC_HOUR, OCC_Month_Encoded, Location_Engineered_Other</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.28</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.18</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1455.21</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.47</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.30</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 65:</b> OCC_YEAR, OCC_HOUR, OCC_Month_Encoded, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.29</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.25</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1742.90</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.17</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.35</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 66:</b> OCC_YEAR, OCC_HOUR, OCC_Month_Encoded, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.30</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.26</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1773.79</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.22</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.49</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
# ...
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>-0.07</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.46</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2193:</b> LAT_WGS84, OCC_Month_Encoded, OCC_DOW_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.30</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.29</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2364.05</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.25</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.62</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2194:</b> LAT_WGS84, OCC_Month_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.28</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.31</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1581.28</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.08</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.60</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2195:</b> LAT_WGS84, OCC_Month_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.28</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.33</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1579.28</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.08</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.60</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2196:</b> LAT_WGS84, OCC_Month_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.33</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.16</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2366.14</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.08</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.63</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2197:</b> LAT_WGS84, OCC_Month_Encoded, Hood_158_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.36</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.15</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2484.40</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.22</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.35</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2198:</b> LAT_WGS84, OCC_Month_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.36</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.06</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2743.82</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.15</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.66</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2199:</b> LAT_WGS84, OCC_DOW_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.28</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.31</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1585.12</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.18</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.56</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2200:</b> LAT_WGS84, OCC_DOW_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.19</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.70</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1011.74</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.18</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.56</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2201:</b> LAT_WGS84, OCC_DOW_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.33</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.16</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2370.71</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.15</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.58</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2202:</b> LAT_WGS84, OCC_DOW_Encoded, Hood_158_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.35</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.17</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2431.82</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.33</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.33</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2203:</b> LAT_WGS84, OCC_DOW_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.36</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.06</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2749.84</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.21</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.66</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2204:</b> LAT_WGS84, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.43</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>0.93</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2951.02</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.37</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.08</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2205:</b> OCC_Month_Encoded, OCC_DOW_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.26</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.37</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1490.86</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.12</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.87</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2206:</b> OCC_Month_Encoded, OCC_DOW_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.25</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.60</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1277.33</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.13</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.87</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2207:</b> OCC_Month_Encoded, OCC_DOW_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.24</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.61</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>1628.78</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.09</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.89</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2208:</b> OCC_Month_Encoded, OCC_DOW_Encoded, Hood_158_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.35</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.10</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2261.25</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.45</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.22</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2209:</b> OCC_Month_Encoded, OCC_DOW_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.34</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.17</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2526.51</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.14</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>2.28</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2210:</b> OCC_Month_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.40</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.02</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2772.79</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.28</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.65</span></p>
#     </div>
#     <div style="border: 2px solid #ddd; padding: 10px; margin: 5px 0; background-color: #f9f9f9;">
#         <p><b>Feature Set 2211:</b> OCC_DOW_Encoded, Hood_158_Encoded, Division_Encoded, Location_Engineered_Other, Location_Engineered_Public, Location_Engineered_Residential</p>
#         <p>KMeans Silhouette Score: <span style='color: #ffcc00; font-weight: bold;'>0.41</span></p>
#         <p>KMeans Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.08</span></p>
#         <p>KMeans Calinski-Harabasz Score: <span style='color: #ff6347; font-weight: bold;'>2789.51</span></p>
#         <p>DBSCAN Silhouette Score: <span style='color: #32cd32; font-weight: bold;'>0.27</span></p>
#         <p>DBSCAN Davies-Bouldin Index: <span style='color: #32cd32; font-weight: bold;'>1.83</span></p>
#     </div>
# <h2 style='color: navy; font-size:18px;'><b> Total Models Trained: 2211</b></h2>
# <div style="font-family: Arial, sans-serif; font-size: 18px; padding: 15px; border-radius: 10px;
#              background: #282c34; color: #61dafb; text-align: center; width: 60%; margin: 20px auto;
#              box-shadow: 2px 2px 10px rgba(0,0,0,0.2);">
#     <strong>Total K-Means & DBCSCAN Clustering models trained:</strong> <span style="color: #ffcc00; font-size: 22px;">2211</span>
# </div>
