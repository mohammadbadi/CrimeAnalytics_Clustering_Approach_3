# %% [markdown]
# <a href="https://www.kaggle.com/code/maddi007py/5-4-2-data-reduction-and-projection-e-eda?scriptVersionId=227978432" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
